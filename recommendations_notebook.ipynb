# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import re
import scipy.sparse as sparse
from lightfm import LightFM
from lightfm.cross_validation import random_train_test_split
from lightfm.evaluation import precision_at_k, recall_at_k, auc_score
from sklearn.metrics import roc_auc_score, f1_score, roc_curve
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from tqdm import tqdm

from catboost import CatBoostClassifier
from pandas_profiling import ProfileReport

# %matplotlib inline

# %% [markdown]
# ### Data loading

# %%
train = pd.read_csv('train.csv', low_memory=False)
test = pd.read_csv('test.csv', low_memory=False)
submission = pd.read_csv('sample_submission.csv', low_memory=False)

# %%
train_data, test_data = train_test_split(train, test_size=0.2, shuffle=True, random_state=42)

# %%
# train_data = train
# test_data = test

# %% [markdown]
# ### Simple features-free modeling with LightFM

# %%
ratings_coo = sparse.coo_matrix((train_data.rating.astype(int), 
                                 (train_data.userid, train_data.itemid)))

# %%
# lr_list = [0.11, 0.12, 0.13, 0.15, 0.17, 0.2, 0.25, 0.3]
# comp_list = [10, 15, 20, 25, 30, 50, 100, 150, 300]

lr_list = [0.17]
comp_list = [105]

score_list = []
params = []

# %%
for lr in tqdm(lr_list):
    for comp in comp_list:
        for ep in [11]:
            model = LightFM(learning_rate=lr, loss='logistic', no_components=comp, 
                            learning_schedule='adagrad')
            model = model.fit(ratings_coo, epochs=ep, num_threads=16)
            preds = model.predict(test_data.userid.values, test_data.itemid.values)
            preds_norm = ((preds-preds.min()) / (preds-preds.min()).max())
            roc_auc = roc_auc_score(test_data.rating.values, preds_norm)
            params.append([lr, comp])
            score_list.append(roc_auc)
            print(f'epochs = {ep}')
            print(f'lr = {lr}, comp = {comp}')
            print(f'roc_auc_score = {roc_auc}')
            print('######################################################')
        
max_idx = np.argmax(np.array(score_list))
print()
print(f'epoch = {ep}')
print(score_list[max_idx])
print(params[max_idx])
# Out:
# 100%|██████████| 1/1 [00:24<00:00, 24.18s/it]
# epochs = 11
# lr = 0.17, comp = 105
# roc_auc_score = 0.7586849820085277
# ######################################################
#
# epoch = 11
# 0.7586849820085277
# [0.17, 105]

# %% [markdown]
# ### Data analysis and cleaning

# %%
with open('meta_Grocery_and_Gourmet_Food.json', 'rb') as file:
    meta_list = []
    for line in file.readlines():
        meta_list.append(json.loads(line))

# %%
meta = pd.DataFrame(meta_list)

# %%
train_full = pd.merge(train, meta, on='asin')

# %%
columns_to_drop = [
    'reviewTime',
    'reviewerName',
    'style',
    'image_x',
    'image_y',
    'date',
    'feature',
    'details',
    'tech1',
    'fit', 
    'similar_item', 
    'vote']

# %%
def clean_data(input_data):
    data = input_data.drop(columns_to_drop, axis=1)
    data.summary.fillna('Nothing', inplace=True)
    data.brand.fillna('No brand', inplace=True)
    data.also_view.fillna(0.0, inplace = True)
    data.also_buy.fillna(0.0, inplace = True)
    data.description.fillna('No description', inplace=True)
    data['rank'].fillna('0,0', inplace=True)
    data['reviewText'].fillna('No review', inplace=True)
    data['main_cat'].fillna('No cat', inplace=True)
    
    cat_df = pd.DataFrame(data.category.values.tolist(), 
                          index=data.index, dtype=str).add_prefix('category_')
    cat_df.fillna('No category', inplace=True)
    data = pd.concat([data, cat_df.iloc[:, :4]], axis=1)
    
    data['description'] = data.description.map(lambda x: ' '.join(x))
    data['price'] = data.price.str.findall(r'\d+\.\d+').apply(lambda x: 
                                                              x if type(x)!=list else x[0]).astype('float64')
    data.price.fillna(data.groupby('itemid').price.count())
    data['also_view'] = data.also_view.apply(lambda x: 0 if type(x)!=list else len(x))
    data['also_buy'] = data.also_buy.apply(lambda x: 0 if type(x)!=list else len(x))
    data['verified'] = data.verified.map({True:1, False:0})
    data['rank'] = data['rank'].str.findall('\d+,+\d+').map(lambda x: float(x[0].replace(',', '.')) 
                                                            if ((type(x)==list)
                                                            and (len(x)!=0)) else 0.0)
    data.drop('category', axis=1, inplace=True)
    data['price'].fillna(0.0, inplace=True)
    
    return data

# %%
# profile = ProfileReport(meta, title='Pandas Profiling Report', explorative=True)

# %%
sample = train_full.sample(frac=1)

# %%
# sns.heatmap(sample.isna(), cmap='plasma')

# %% [markdown]
# ### Data splitting

# %%
data_sample = clean_data(sample)

# %%
data_sample.columns
# Out:
# Index(['overall', 'verified', 'asin', 'reviewText', 'summary',
#        'unixReviewTime', 'userid', 'itemid', 'rating', 'description', 'title',
#        'brand', 'rank', 'also_view', 'main_cat', 'price', 'also_buy',
#        'category_0', 'category_1', 'category_2', 'category_3'],
#       dtype='object')

# %%
num_features = ['unixReviewTime', 'price', 'rank', 'also_view', 'also_buy',]
cat_features = ['verified', 'asin', 'userid', 'itemid',]# 'brand', 'main_cat', 
#                'category_0', 'category_1', 'category_2', 'category_3']
text_features = ['reviewText', 'summary', 'title',]# 'description']

target_features = ['overall', 'rating']

# %%
X, y = data_sample.drop(target_features, axis=1), data_sample.rating

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.3, shuffle=True, random_state=42)

# %% [markdown]
# ### Custom "mean" encoding

# %%
def make_rating_mean_count(df_mean_train, df_mean_test, col, df_train, df_test, group_cols=None):
    
    # функция добавляет в df_mean_train и df_mean_test столбцы средней цены/количества объявлений
    # для каждого категориального признака col. group_cols - лист с дополнительными признаками,
    # которые позволяют группировать рейтинг/количества по связке "признаки group_cols + признак col"
    
    join_cols = []
    
    if (group_cols!=None) and (col not in group_cols):
        join_cols.append(col) 
        join_cols += group_cols
    else:
        join_cols.append(col)
    df_mean_train[col+'_rating_mean'] = df_train[join_cols].merge(df_train.groupby(by=join_cols, as_index=False).
                                                                 rating.median(), on=join_cols, how='left').iloc[:,-1]
    df_mean_test[col+'_rating_mean'] = df_test[join_cols].merge(df_train.groupby(by=join_cols, as_index=False).
                                                               rating.median(), on=join_cols, how='left').iloc[:,-1]
    df_mean_train[col+'_count'] = df_train[join_cols].merge(df_train.groupby(by=join_cols, as_index=False).
                                                            rating.count(), on=join_cols, how='left').iloc[:,-1]
    df_mean_test[col+'_count'] = df_test[join_cols].merge(df_train.groupby(by=join_cols, as_index=False).
                                                          rating.count(), on=join_cols, how='left').iloc[:,-1]   
    
    if col == 'model': 
        df_mean_test[col+'_rating_mean'] = df_mean_test[col+'_rating_mean'].\
        fillna(df_mean_test['brand_rating_mean']) 
        
        df_mean_test[col+'_count'] = df_mean_test[col+'_count'].\
        fillna(df_mean_test['brand_count'])
    
    if col == 'model_name':
        df_mean_test[col+'_rating_mean'] = df_mean_test[col+'_rating_mean'].\
        fillna(df_mean_test['model_rating_mean']).\
        fillna(df_mean_test['brand_rating_mean'])    
        
        df_mean_test[col+'_count'] = df_mean_test[col+'_count'].\
        fillna(df_mean_test['model_count']).\
        fillna(df_mean_test['brand_count'])  
    
    if col == 'modification':
        df_mean_test[col+'_rating_mean'] = df_mean_test[col+'_rating_mean'].\
        fillna(df_mean_test['model_name_rating_mean']).fillna(df_mean_test['model_rating_mean']).\
        fillna(df_mean_test['brand_rating_mean'])    
        
        df_mean_test[col+'_count'] = df_mean_test[col+'_count'].\
        fillna(df_mean_test['model_name_count']).fillna(df_mean_test['model_count']).\
        fillna(df_mean_test['brand_count'])
        
        
    other_filler_rating_mean = df_mean_test[f'{col}_rating_mean'].median()
    df_mean_test[f'{col}_rating_mean'] = df_mean_test[f'{col}_rating_mean'].fillna(other_filler_rating_mean)

    other_filler_count = df_mean_test[f'{col}_count'].median()
    df_mean_test[f'{col}_count'] = df_mean_test[f'{col}_count'].fillna(other_filler_count)



def make_num_feat_mean(df_mean_train, df_mean_test, col, num_col, df_train, df_test, group_cols=None):
    
    # аналогичная функция, но кодирует категориальные признаки по средним значениям числовых колонок (num_features)
    
    if col in ['itemid', 'userid']:
        join_cols = []

        if (group_cols!=None) and (col not in group_cols):
            join_cols.append(col) 
            join_cols += group_cols
        else:
            join_cols.append(col)

        df_mean_train[f'{col}_{num_col}_mean'] = df_train[join_cols].merge(df_train.groupby(by=join_cols, as_index=False)\
                                                               [num_col].mean(), on=join_cols, how='left').iloc[:,-1]

        df_mean_test[f'{col}_{num_col}_mean'] = df_test[join_cols].merge(df_train.groupby(by=join_cols, as_index=False)\
                                                               [num_col].mean(), on=join_cols, how='left').iloc[:,-1]

        if col == 'model': 
            df_mean_test[f'{col}_{num_col}_mean'] = df_mean_test[f'{col}_{num_col}_mean'].\
            fillna(df_mean_test[f'brand_{num_col}_mean']) 

        if col == 'model_name':
            df_mean_test[f'{col}_{num_col}_mean'] = df_mean_test[f'{col}_{num_col}_mean'].\
            fillna(df_mean_test[f'model_{num_col}_mean']).\
            fillna(df_mean_test[f'brand_{num_col}_mean'])    

        if col == 'modification':
            df_mean_test[f'{col}_{num_col}_mean'] = df_mean_test[f'{col}_{num_col}_mean'].\
            fillna(df_mean_test[f'model_name_{num_col}_mean']).fillna(df_mean_test[f'model_{num_col}_mean']).\
            fillna(df_mean_test[f'brand_{num_col}_mean'])    

        other_filler = df_mean_test[f'{col}_{num_col}_mean'].median()
        df_mean_test[f'{col}_{num_col}_mean'] = df_mean_test[f'{col}_{num_col}_mean'].fillna(other_filler)

# %%
# получаем индексы train и test выборок
train_idx = y_train.index.values
test_idx = y_test.index.values

# добавляем таргет и получаем 2 выборки "признак=таргет"
df_train = data_sample.loc[train_idx]
df_test = data_sample.loc[test_idx]

# пустые фреймы для mean/count encoding features
df_mean_train = pd.DataFrame(index=train_idx)
df_mean_test = pd.DataFrame(index=test_idx)

# создаем кодированные категориальные признаки
for col in cat_features:
    make_rating_mean_count(df_mean_train, df_mean_test, col, df_train, df_test, group_cols=None)
    for num_col in num_features:
        make_num_feat_mean(df_mean_train, df_mean_test, col, num_col, df_train, df_test, group_cols=None)
        
mean_columns = df_mean_test.columns

X_train_cat = np.array(df_mean_train)
X_test_cat = np.array(df_mean_test)
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)

# %% [markdown]
# ### Vectorizing text features

# %%
vectorizer = TfidfVectorizer(stop_words='english', analyzer='word')

# %%
# i = 0
# for col in text_features:
#     if i==0:
#         X_train_text = vectorizer.fit_transform(X_train[col])
#         X_test_text = vectorizer.transform(X_test[col])
#         text_fi_cols = vectorizer.get_feature_names()
#         continue
#     X_train_text = sparse.hstack([X_train_text, vectorizer.fit_transform(X_train[col])])
#     X_test_text = sparse.hstack([X_test_text, vectorizer.transform(X_test[col])])
#     text_fi_cols += vectorizer.get_feature_names()

# %%
# X_train_final = np.hstack([X_train[num_features], X_train_cat,])# X_train_text])
X_train_final = np.hstack([X_train_cat,])# X_train_text])

# %%
# X_test_final = np.hstack([X_test[num_features], X_test_cat, ])#X_test_text])
X_test_final = np.hstack([X_test_cat, ])#X_test_text])

# %% [markdown]
# ## Моделирование

# %%
estimator = CatBoostClassifier(depth=7, iterations=1000, learning_rate=0.1, verbose=True, random_state=42)

# %%
estimator.fit(X_train_final, y_train)
# Out:
# 0:	learn: 0.6363537	total: 78.3ms	remaining: 1m 18s
# 1:	learn: 0.5915996	total: 177ms	remaining: 1m 28s
# 2:	learn: 0.5563786	total: 266ms	remaining: 1m 28s
# 3:	learn: 0.5286615	total: 369ms	remaining: 1m 31s
# 4:	learn: 0.5068532	total: 466ms	remaining: 1m 32s
# 5:	learn: 0.4896524	total: 581ms	remaining: 1m 36s
# 6:	learn: 0.4760845	total: 698ms	remaining: 1m 39s
# 7:	learn: 0.4653628	total: 821ms	remaining: 1m 41s
# 8:	learn: 0.4568625	total: 930ms	remaining: 1m 42s
# 9:	learn: 0.4501376	total: 1s	remaining: 1m 39s
# 10:	learn: 0.4447852	total: 1.11s	remaining: 1m 39s
# 11:	learn: 0.4405362	total: 1.18s	remaining: 1m 37s
# 12:	learn: 0.4371475	total: 1.27s	remaining: 1m 36s
# 13:	learn: 0.4344367	total: 1.37s	remaining: 1m 36s
# 14:	learn: 0.4322730	total: 1.45s	remaining: 1m 35s
# 15:	learn: 0.4305465	total: 1.49s	remaining: 1m 31s
# 16:	learn: 0.4291465	total: 1.57s	remaining: 1m 30s
# 17:	learn: 0.4280297	total: 1.68s	remaining: 1m 31s
# 18:	learn: 0.4271296	total: 1.77s	remaining: 1m 31s
# 19:	learn: 0.4264042	total: 1.86s	remaining: 1m 31s
# 20:	learn: 0.4258225	total: 1.96s	remaining: 1m 31s
# 21:	learn: 0.4253523	total: 2.03s	remaining: 1m 30s
# 22:	learn: 0.4249664	total: 2.12s	remaining: 1m 30s
# 23:	learn: 0.4246653	total: 2.23s	remaining: 1m 30s
# 24:	learn: 0.4244125	total: 2.36s	remaining: 1m 32s
# 25:	learn: 0.4242130	total: 2.49s	remaining: 1m 33s
# 26:	learn: 0.4240562	total: 2.56s	remaining: 1m 32s
# 27:	learn: 0.4239296	total: 2.62s	remaining: 1m 31s
# 28:	learn: 0.4238134	total: 2.73s	remaining: 1m 31s
# 29:	learn: 0.4237209	total: 2.83s	remaining: 1m 31s
# 30:	learn: 0.4236475	total: 2.9s	remaining: 1m 30s
# 31:	learn: 0.4235881	total: 2.99s	remaining: 1m 30s
# 32:	learn: 0.4235446	total: 3.05s	remaining: 1m 29s
# 33:	learn: 0.4234963	total: 3.16s	remaining: 1m 29s
# 34:	learn: 0.4234585	total: 3.25s	remaining: 1m 29s
# 35:	learn: 0.4234265	total: 3.32s	remaining: 1m 28s
# 36:	learn: 0.4233973	total: 3.38s	remaining: 1m 28s
# 37:	learn: 0.4233679	total: 3.45s	remaining: 1m 27s
# 38:	learn: 0.4233479	total: 3.54s	remaining: 1m 27s
# 39:	learn: 0.4233336	total: 3.61s	remaining: 1m 26s
# 40:	learn: 0.4233061	total: 3.7s	remaining: 1m 26s
# 41:	learn: 0.4232873	total: 3.79s	remaining: 1m 26s
# 42:	learn: 0.4232820	total: 3.84s	remaining: 1m 25s
# 43:	learn: 0.4232533	total: 3.96s	remaining: 1m 25s
# 44:	learn: 0.4232320	total: 4.06s	remaining: 1m 26s
# 45:	learn: 0.4232157	total: 4.17s	remaining: 1m 26s
# 46:	learn: 0.4231941	total: 4.26s	remaining: 1m 26s
# 47:	learn: 0.4231764	total: 4.34s	remaining: 1m 26s
# 48:	learn: 0.4231539	total: 4.44s	remaining: 1m 26s
# 49:	learn: 0.4231264	total: 4.55s	remaining: 1m 26s
# 50:	learn: 0.4231089	total: 4.66s	remaining: 1m 26s
# 51:	learn: 0.4230975	total: 4.73s	remaining: 1m 26s
# 52:	learn: 0.4230823	total: 4.82s	remaining: 1m 26s
# 53:	learn: 0.4230598	total: 4.91s	remaining: 1m 26s
# 54:	learn: 0.4230404	total: 4.99s	remaining: 1m 25s
# 55:	learn: 0.4230176	total: 5.06s	remaining: 1m 25s
# 56:	learn: 0.4229996	total: 5.14s	remaining: 1m 24s
# 57:	learn: 0.4229907	total: 5.21s	remaining: 1m 24s
# 58:	learn: 0.4229751	total: 5.28s	remaining: 1m 24s
# 59:	learn: 0.4229490	total: 5.36s	remaining: 1m 23s
# 60:	learn: 0.4229300	total: 5.43s	remaining: 1m 23s
# 61:	learn: 0.4229075	total: 5.53s	remaining: 1m 23s
# 62:	learn: 0.4228852	total: 5.63s	remaining: 1m 23s
# 63:	learn: 0.4228631	total: 5.71s	remaining: 1m 23s
# 64:	learn: 0.4228512	total: 5.78s	remaining: 1m 23s
# 65:	learn: 0.4228310	total: 5.85s	remaining: 1m 22s
# 66:	learn: 0.4228141	total: 5.92s	remaining: 1m 22s
# 67:	learn: 0.4227971	total: 5.98s	remaining: 1m 22s
# 68:	learn: 0.4227829	total: 6.11s	remaining: 1m 22s
# 69:	learn: 0.4227744	total: 6.25s	remaining: 1m 23s
# 70:	learn: 0.4227634	total: 6.4s	remaining: 1m 23s
# 71:	learn: 0.4227537	total: 6.48s	remaining: 1m 23s
# 72:	learn: 0.4227353	total: 6.57s	remaining: 1m 23s
# 73:	learn: 0.4227268	total: 6.67s	remaining: 1m 23s
# 74:	learn: 0.4227128	total: 6.74s	remaining: 1m 23s
# 75:	learn: 0.4226883	total: 6.82s	remaining: 1m 22s
# 76:	learn: 0.4226653	total: 6.91s	remaining: 1m 22s
# 77:	learn: 0.4226439	total: 7.01s	remaining: 1m 22s
# 78:	learn: 0.4226369	total: 7.1s	remaining: 1m 22s
# 79:	learn: 0.4226271	total: 7.2s	remaining: 1m 22s
# 80:	learn: 0.4226122	total: 7.28s	remaining: 1m 22s
# 81:	learn: 0.4225991	total: 7.34s	remaining: 1m 22s
# 82:	learn: 0.4225770	total: 7.42s	remaining: 1m 21s
# 83:	learn: 0.4225560	total: 7.5s	remaining: 1m 21s
# 84:	learn: 0.4225386	total: 7.57s	remaining: 1m 21s
# 85:	learn: 0.4225290	total: 7.64s	remaining: 1m 21s
# 86:	learn: 0.4225108	total: 7.71s	remaining: 1m 20s
# 87:	learn: 0.4224983	total: 7.78s	remaining: 1m 20s
# 88:	learn: 0.4224847	total: 7.87s	remaining: 1m 20s
# 89:	learn: 0.4224659	total: 7.97s	remaining: 1m 20s
# 90:	learn: 0.4224513	total: 8.07s	remaining: 1m 20s
# 91:	learn: 0.4224333	total: 8.15s	remaining: 1m 20s
# 92:	learn: 0.4224157	total: 8.23s	remaining: 1m 20s
# 93:	learn: 0.4223954	total: 8.31s	remaining: 1m 20s
# 94:	learn: 0.4223801	total: 8.4s	remaining: 1m 20s
# 95:	learn: 0.4223647	total: 8.5s	remaining: 1m 20s
# 96:	learn: 0.4223470	total: 8.59s	remaining: 1m 19s
# 97:	learn: 0.4223292	total: 8.67s	remaining: 1m 19s
# 98:	learn: 0.4223129	total: 8.73s	remaining: 1m 19s
# 99:	learn: 0.4222959	total: 8.8s	remaining: 1m 19s
# 100:	learn: 0.4222813	total: 8.88s	remaining: 1m 19s
# 101:	learn: 0.4222729	total: 8.96s	remaining: 1m 18s
# 102:	learn: 0.4222531	total: 9.03s	remaining: 1m 18s
# 103:	learn: 0.4222346	total: 9.1s	remaining: 1m 18s
# 104:	learn: 0.4222153	total: 9.18s	remaining: 1m 18s
# 105:	learn: 0.4222007	total: 9.27s	remaining: 1m 18s
# 106:	learn: 0.4221834	total: 9.4s	remaining: 1m 18s
# 107:	learn: 0.4221643	total: 9.54s	remaining: 1m 18s
# 108:	learn: 0.4221415	total: 9.68s	remaining: 1m 19s
# 109:	learn: 0.4221243	total: 9.82s	remaining: 1m 19s
# 110:	learn: 0.4221016	total: 9.95s	remaining: 1m 19s
# 111:	learn: 0.4220877	total: 10.1s	remaining: 1m 19s
# 112:	learn: 0.4220830	total: 10.2s	remaining: 1m 19s
# 113:	learn: 0.4220608	total: 10.2s	remaining: 1m 19s
# 114:	learn: 0.4220463	total: 10.3s	remaining: 1m 19s
# 115:	learn: 0.4220247	total: 10.4s	remaining: 1m 19s
# 116:	learn: 0.4220174	total: 10.5s	remaining: 1m 19s
# 117:	learn: 0.4220044	total: 10.5s	remaining: 1m 18s
# 118:	learn: 0.4219970	total: 10.6s	remaining: 1m 18s
# 119:	learn: 0.4219968	total: 10.7s	remaining: 1m 18s
# 120:	learn: 0.4219738	total: 10.8s	remaining: 1m 18s
# 121:	learn: 0.4219618	total: 10.9s	remaining: 1m 18s
# 122:	learn: 0.4219424	total: 10.9s	remaining: 1m 17s
# 123:	learn: 0.4219201	total: 11s	remaining: 1m 17s
# 124:	learn: 0.4219066	total: 11.1s	remaining: 1m 17s
# 125:	learn: 0.4218942	total: 11.2s	remaining: 1m 17s
# 126:	learn: 0.4218733	total: 11.3s	remaining: 1m 17s
# 127:	learn: 0.4218573	total: 11.4s	remaining: 1m 17s
# 128:	learn: 0.4218436	total: 11.5s	remaining: 1m 17s
# 129:	learn: 0.4218304	total: 11.5s	remaining: 1m 17s
# 130:	learn: 0.4218180	total: 11.6s	remaining: 1m 17s
# 131:	learn: 0.4218020	total: 11.7s	remaining: 1m 16s
# 132:	learn: 0.4217796	total: 11.8s	remaining: 1m 16s
# 133:	learn: 0.4217634	total: 11.9s	remaining: 1m 16s
# 134:	learn: 0.4217435	total: 12s	remaining: 1m 16s
# 135:	learn: 0.4217272	total: 12s	remaining: 1m 16s
# 136:	learn: 0.4217096	total: 12.1s	remaining: 1m 16s
# 137:	learn: 0.4216923	total: 12.2s	remaining: 1m 16s
# 138:	learn: 0.4216792	total: 12.3s	remaining: 1m 16s
# 139:	learn: 0.4216616	total: 12.4s	remaining: 1m 16s
# 140:	learn: 0.4216395	total: 12.4s	remaining: 1m 15s
# 141:	learn: 0.4216172	total: 12.5s	remaining: 1m 15s
# 142:	learn: 0.4215944	total: 12.6s	remaining: 1m 15s
# 143:	learn: 0.4215786	total: 12.7s	remaining: 1m 15s
# 144:	learn: 0.4215617	total: 12.8s	remaining: 1m 15s
# 145:	learn: 0.4215361	total: 12.9s	remaining: 1m 15s
# 146:	learn: 0.4215111	total: 12.9s	remaining: 1m 15s
# 147:	learn: 0.4215006	total: 13s	remaining: 1m 14s
# 148:	learn: 0.4214775	total: 13.1s	remaining: 1m 14s
# 149:	learn: 0.4214591	total: 13.2s	remaining: 1m 14s
# 150:	learn: 0.4214353	total: 13.2s	remaining: 1m 14s
# 151:	learn: 0.4214141	total: 13.4s	remaining: 1m 14s
# 152:	learn: 0.4213967	total: 13.5s	remaining: 1m 14s
# 153:	learn: 0.4213722	total: 13.6s	remaining: 1m 14s
# 154:	learn: 0.4213555	total: 13.7s	remaining: 1m 14s
# 155:	learn: 0.4213319	total: 13.8s	remaining: 1m 14s
# 156:	learn: 0.4213061	total: 13.9s	remaining: 1m 14s
# 157:	learn: 0.4212787	total: 14s	remaining: 1m 14s
# 158:	learn: 0.4212587	total: 14s	remaining: 1m 14s
# 159:	learn: 0.4212388	total: 14.1s	remaining: 1m 14s
# 160:	learn: 0.4212159	total: 14.2s	remaining: 1m 13s
# 161:	learn: 0.4211932	total: 14.3s	remaining: 1m 13s
# 162:	learn: 0.4211640	total: 14.3s	remaining: 1m 13s
# 163:	learn: 0.4211393	total: 14.4s	remaining: 1m 13s
# 164:	learn: 0.4211170	total: 14.5s	remaining: 1m 13s
# 165:	learn: 0.4210907	total: 14.5s	remaining: 1m 13s
# 166:	learn: 0.4210690	total: 14.6s	remaining: 1m 12s
# 167:	learn: 0.4210515	total: 14.7s	remaining: 1m 12s
# 168:	learn: 0.4210246	total: 14.8s	remaining: 1m 12s
# 169:	learn: 0.4210112	total: 14.8s	remaining: 1m 12s
# 170:	learn: 0.4209914	total: 14.9s	remaining: 1m 12s
# 171:	learn: 0.4209724	total: 15s	remaining: 1m 12s
# 172:	learn: 0.4209552	total: 15.1s	remaining: 1m 12s
# 173:	learn: 0.4209349	total: 15.2s	remaining: 1m 12s
# 174:	learn: 0.4209143	total: 15.3s	remaining: 1m 12s
# 175:	learn: 0.4208901	total: 15.4s	remaining: 1m 12s
# 176:	learn: 0.4208697	total: 15.5s	remaining: 1m 12s
# 177:	learn: 0.4208477	total: 15.6s	remaining: 1m 11s
# 178:	learn: 0.4208298	total: 15.7s	remaining: 1m 11s
# 179:	learn: 0.4208068	total: 15.8s	remaining: 1m 11s
# 180:	learn: 0.4207921	total: 15.9s	remaining: 1m 11s
# 181:	learn: 0.4207694	total: 16s	remaining: 1m 11s
# 182:	learn: 0.4207552	total: 16.1s	remaining: 1m 11s
# 183:	learn: 0.4207380	total: 16.2s	remaining: 1m 11s
# 184:	learn: 0.4207167	total: 16.3s	remaining: 1m 11s
# 185:	learn: 0.4206986	total: 16.4s	remaining: 1m 11s
# 186:	learn: 0.4206842	total: 16.4s	remaining: 1m 11s
# 187:	learn: 0.4206656	total: 16.5s	remaining: 1m 11s
# 188:	learn: 0.4206497	total: 16.6s	remaining: 1m 11s
# 189:	learn: 0.4206335	total: 16.7s	remaining: 1m 11s
# 190:	learn: 0.4206156	total: 16.8s	remaining: 1m 11s
# 191:	learn: 0.4205935	total: 17s	remaining: 1m 11s
# 192:	learn: 0.4205826	total: 17s	remaining: 1m 11s
# 193:	learn: 0.4205637	total: 17.1s	remaining: 1m 11s
# 194:	learn: 0.4205382	total: 17.2s	remaining: 1m 10s
# 195:	learn: 0.4205201	total: 17.3s	remaining: 1m 10s
# 196:	learn: 0.4205025	total: 17.4s	remaining: 1m 10s
# 197:	learn: 0.4204847	total: 17.5s	remaining: 1m 10s
# 198:	learn: 0.4204626	total: 17.5s	remaining: 1m 10s
# 199:	learn: 0.4204405	total: 17.6s	remaining: 1m 10s
# 200:	learn: 0.4204260	total: 17.7s	remaining: 1m 10s
# 201:	learn: 0.4203972	total: 17.8s	remaining: 1m 10s
# 202:	learn: 0.4203779	total: 17.9s	remaining: 1m 10s
# 203:	learn: 0.4203604	total: 18.1s	remaining: 1m 10s
# 204:	learn: 0.4203411	total: 18.2s	remaining: 1m 10s
# 205:	learn: 0.4203283	total: 18.3s	remaining: 1m 10s
# 206:	learn: 0.4203064	total: 18.3s	remaining: 1m 10s
# 207:	learn: 0.4202903	total: 18.4s	remaining: 1m 10s
# 208:	learn: 0.4202750	total: 18.5s	remaining: 1m 9s
# 209:	learn: 0.4202560	total: 18.5s	remaining: 1m 9s
# 210:	learn: 0.4202372	total: 18.6s	remaining: 1m 9s
# 211:	learn: 0.4202186	total: 18.7s	remaining: 1m 9s
# 212:	learn: 0.4202048	total: 18.8s	remaining: 1m 9s
# 213:	learn: 0.4201855	total: 18.8s	remaining: 1m 9s
# 214:	learn: 0.4201660	total: 18.9s	remaining: 1m 9s
# 215:	learn: 0.4201455	total: 19s	remaining: 1m 9s
# 216:	learn: 0.4201243	total: 19.1s	remaining: 1m 8s
# 217:	learn: 0.4201093	total: 19.2s	remaining: 1m 8s
# 218:	learn: 0.4200917	total: 19.2s	remaining: 1m 8s
# 219:	learn: 0.4200673	total: 19.3s	remaining: 1m 8s
# 220:	learn: 0.4200462	total: 19.4s	remaining: 1m 8s
# 221:	learn: 0.4200309	total: 19.5s	remaining: 1m 8s
# 222:	learn: 0.4200107	total: 19.5s	remaining: 1m 8s
# 223:	learn: 0.4199936	total: 19.6s	remaining: 1m 7s
# 224:	learn: 0.4199660	total: 19.7s	remaining: 1m 7s
# 225:	learn: 0.4199414	total: 19.8s	remaining: 1m 7s
# 226:	learn: 0.4199226	total: 19.8s	remaining: 1m 7s
# 227:	learn: 0.4199010	total: 19.9s	remaining: 1m 7s
# 228:	learn: 0.4198763	total: 20s	remaining: 1m 7s
# 229:	learn: 0.4198554	total: 20.1s	remaining: 1m 7s
# 230:	learn: 0.4198295	total: 20.1s	remaining: 1m 7s
# 231:	learn: 0.4198110	total: 20.2s	remaining: 1m 6s
# 232:	learn: 0.4197865	total: 20.3s	remaining: 1m 6s
# 233:	learn: 0.4197692	total: 20.4s	remaining: 1m 6s
# 234:	learn: 0.4197464	total: 20.4s	remaining: 1m 6s
# 235:	learn: 0.4197292	total: 20.5s	remaining: 1m 6s
# 236:	learn: 0.4197088	total: 20.6s	remaining: 1m 6s
# 237:	learn: 0.4196873	total: 20.6s	remaining: 1m 6s
# 238:	learn: 0.4196705	total: 20.7s	remaining: 1m 6s
# 239:	learn: 0.4196613	total: 20.8s	remaining: 1m 5s
# 240:	learn: 0.4196429	total: 20.9s	remaining: 1m 5s
# 241:	learn: 0.4196241	total: 21s	remaining: 1m 5s
# 242:	learn: 0.4196059	total: 21s	remaining: 1m 5s
# 243:	learn: 0.4195928	total: 21.1s	remaining: 1m 5s
# 244:	learn: 0.4195775	total: 21.2s	remaining: 1m 5s
# 245:	learn: 0.4195629	total: 21.2s	remaining: 1m 5s
# 246:	learn: 0.4195421	total: 21.3s	remaining: 1m 4s
# 247:	learn: 0.4195273	total: 21.4s	remaining: 1m 4s
# 248:	learn: 0.4195131	total: 21.5s	remaining: 1m 4s
# 249:	learn: 0.4194953	total: 21.5s	remaining: 1m 4s
# 250:	learn: 0.4194832	total: 21.6s	remaining: 1m 4s
# 251:	learn: 0.4194599	total: 21.7s	remaining: 1m 4s
# 252:	learn: 0.4194387	total: 21.7s	remaining: 1m 4s
# 253:	learn: 0.4194149	total: 21.8s	remaining: 1m 4s
# 254:	learn: 0.4193948	total: 21.9s	remaining: 1m 3s
# 255:	learn: 0.4193789	total: 22s	remaining: 1m 3s
# 256:	learn: 0.4193624	total: 22s	remaining: 1m 3s
# 257:	learn: 0.4193480	total: 22.1s	remaining: 1m 3s
# 258:	learn: 0.4193296	total: 22.2s	remaining: 1m 3s
# 259:	learn: 0.4193076	total: 22.3s	remaining: 1m 3s
# 260:	learn: 0.4192910	total: 22.4s	remaining: 1m 3s
# 261:	learn: 0.4192707	total: 22.5s	remaining: 1m 3s
# 262:	learn: 0.4192557	total: 22.6s	remaining: 1m 3s
# 263:	learn: 0.4192342	total: 22.6s	remaining: 1m 3s
# 264:	learn: 0.4192219	total: 22.7s	remaining: 1m 2s
# 265:	learn: 0.4192073	total: 22.8s	remaining: 1m 2s
# 266:	learn: 0.4191902	total: 22.9s	remaining: 1m 2s
# 267:	learn: 0.4191710	total: 22.9s	remaining: 1m 2s
# 268:	learn: 0.4191586	total: 23s	remaining: 1m 2s
# 269:	learn: 0.4191451	total: 23.1s	remaining: 1m 2s
# 270:	learn: 0.4191253	total: 23.2s	remaining: 1m 2s
# 271:	learn: 0.4191115	total: 23.3s	remaining: 1m 2s
# 272:	learn: 0.4190915	total: 23.3s	remaining: 1m 2s
# 273:	learn: 0.4190725	total: 23.4s	remaining: 1m 2s
# 274:	learn: 0.4190505	total: 23.5s	remaining: 1m 1s
# 275:	learn: 0.4190312	total: 23.6s	remaining: 1m 1s
# 276:	learn: 0.4190080	total: 23.6s	remaining: 1m 1s
# 277:	learn: 0.4189854	total: 23.7s	remaining: 1m 1s
# 278:	learn: 0.4189694	total: 23.8s	remaining: 1m 1s
# 279:	learn: 0.4189522	total: 23.9s	remaining: 1m 1s
# 280:	learn: 0.4189341	total: 23.9s	remaining: 1m 1s
# 281:	learn: 0.4189111	total: 24s	remaining: 1m 1s
# 282:	learn: 0.4188890	total: 24.1s	remaining: 1m
# 283:	learn: 0.4188726	total: 24.1s	remaining: 1m
# 284:	learn: 0.4188467	total: 24.2s	remaining: 1m
# 285:	learn: 0.4188289	total: 24.3s	remaining: 1m
# 286:	learn: 0.4188083	total: 24.4s	remaining: 1m
# 287:	learn: 0.4187839	total: 24.5s	remaining: 1m
# 288:	learn: 0.4187577	total: 24.6s	remaining: 1m
# 289:	learn: 0.4187364	total: 24.7s	remaining: 1m
# 290:	learn: 0.4187190	total: 24.7s	remaining: 1m
# 291:	learn: 0.4187014	total: 24.8s	remaining: 1m
# 292:	learn: 0.4186877	total: 24.9s	remaining: 1m
# 293:	learn: 0.4186699	total: 24.9s	remaining: 59.9s
# 294:	learn: 0.4186551	total: 25s	remaining: 59.8s
# 295:	learn: 0.4186415	total: 25.1s	remaining: 59.7s
# 296:	learn: 0.4186277	total: 25.2s	remaining: 59.6s
# 297:	learn: 0.4186051	total: 25.2s	remaining: 59.4s
# 298:	learn: 0.4185911	total: 25.3s	remaining: 59.3s
# 299:	learn: 0.4185775	total: 25.4s	remaining: 59.2s
# 300:	learn: 0.4185571	total: 25.4s	remaining: 59.1s
# 301:	learn: 0.4185372	total: 25.5s	remaining: 59s
# 302:	learn: 0.4185182	total: 25.6s	remaining: 58.9s
# 303:	learn: 0.4185005	total: 25.7s	remaining: 58.8s
# 304:	learn: 0.4184792	total: 25.8s	remaining: 58.7s
# 305:	learn: 0.4184561	total: 25.8s	remaining: 58.6s
# 306:	learn: 0.4184388	total: 25.9s	remaining: 58.5s
# 307:	learn: 0.4184155	total: 26s	remaining: 58.4s
# 308:	learn: 0.4183956	total: 26.1s	remaining: 58.3s
# 309:	learn: 0.4183771	total: 26.1s	remaining: 58.2s
# 310:	learn: 0.4183593	total: 26.2s	remaining: 58.1s
# 311:	learn: 0.4183402	total: 26.3s	remaining: 58s
# 312:	learn: 0.4183289	total: 26.4s	remaining: 57.8s
# 313:	learn: 0.4183083	total: 26.4s	remaining: 57.8s
# 314:	learn: 0.4182921	total: 26.5s	remaining: 57.7s
# 315:	learn: 0.4182766	total: 26.6s	remaining: 57.6s
# 316:	learn: 0.4182519	total: 26.7s	remaining: 57.5s
# 317:	learn: 0.4182356	total: 26.8s	remaining: 57.4s
# 318:	learn: 0.4182166	total: 26.9s	remaining: 57.4s
# 319:	learn: 0.4181993	total: 27s	remaining: 57.3s
# 320:	learn: 0.4181843	total: 27.1s	remaining: 57.2s
# 321:	learn: 0.4181623	total: 27.2s	remaining: 57.2s
# 322:	learn: 0.4181424	total: 27.2s	remaining: 57.1s
# 323:	learn: 0.4181247	total: 27.3s	remaining: 57s
# 324:	learn: 0.4180983	total: 27.4s	remaining: 56.9s
# 325:	learn: 0.4180827	total: 27.5s	remaining: 56.8s
# 326:	learn: 0.4180647	total: 27.5s	remaining: 56.7s
# 327:	learn: 0.4180489	total: 27.6s	remaining: 56.6s
# 328:	learn: 0.4180239	total: 27.7s	remaining: 56.5s
# 329:	learn: 0.4180060	total: 27.8s	remaining: 56.4s
# 330:	learn: 0.4179900	total: 27.8s	remaining: 56.3s
# 331:	learn: 0.4179703	total: 27.9s	remaining: 56.1s
# 332:	learn: 0.4179554	total: 28s	remaining: 56s
# 333:	learn: 0.4179397	total: 28.1s	remaining: 56s
# 334:	learn: 0.4179152	total: 28.1s	remaining: 55.8s
# 335:	learn: 0.4178946	total: 28.2s	remaining: 55.8s
# 336:	learn: 0.4178748	total: 28.3s	remaining: 55.7s
# 337:	learn: 0.4178617	total: 28.4s	remaining: 55.6s
# 338:	learn: 0.4178429	total: 28.4s	remaining: 55.5s
# 339:	learn: 0.4178278	total: 28.5s	remaining: 55.4s
# 340:	learn: 0.4178167	total: 28.6s	remaining: 55.2s
# 341:	learn: 0.4177989	total: 28.7s	remaining: 55.1s
# 342:	learn: 0.4177818	total: 28.7s	remaining: 55s
# 343:	learn: 0.4177700	total: 28.8s	remaining: 54.9s
# 344:	learn: 0.4177550	total: 28.9s	remaining: 54.8s
# 345:	learn: 0.4177358	total: 28.9s	remaining: 54.7s
# 346:	learn: 0.4177210	total: 29s	remaining: 54.6s
# 347:	learn: 0.4177121	total: 29.1s	remaining: 54.5s
# 348:	learn: 0.4176919	total: 29.2s	remaining: 54.4s
# 349:	learn: 0.4176787	total: 29.2s	remaining: 54.3s
# 350:	learn: 0.4176630	total: 29.3s	remaining: 54.2s
# 351:	learn: 0.4176477	total: 29.4s	remaining: 54.1s
# 352:	learn: 0.4176298	total: 29.4s	remaining: 54s
# 353:	learn: 0.4176150	total: 29.5s	remaining: 53.9s
# 354:	learn: 0.4175964	total: 29.6s	remaining: 53.8s
# 355:	learn: 0.4175746	total: 29.7s	remaining: 53.7s
# 356:	learn: 0.4175653	total: 29.7s	remaining: 53.6s
# 357:	learn: 0.4175420	total: 29.8s	remaining: 53.5s
# 358:	learn: 0.4175196	total: 29.9s	remaining: 53.4s
# 359:	learn: 0.4175047	total: 30s	remaining: 53.3s
# 360:	learn: 0.4174794	total: 30s	remaining: 53.2s
# 361:	learn: 0.4174575	total: 30.1s	remaining: 53.1s
# 362:	learn: 0.4174430	total: 30.2s	remaining: 53.1s
# 363:	learn: 0.4174303	total: 30.3s	remaining: 53s
# 364:	learn: 0.4174031	total: 30.4s	remaining: 52.9s
# 365:	learn: 0.4173816	total: 30.5s	remaining: 52.8s
# 366:	learn: 0.4173629	total: 30.5s	remaining: 52.7s
# 367:	learn: 0.4173506	total: 30.6s	remaining: 52.6s
# 368:	learn: 0.4173337	total: 30.7s	remaining: 52.5s
# 369:	learn: 0.4173196	total: 30.8s	remaining: 52.4s
# 370:	learn: 0.4173008	total: 30.8s	remaining: 52.3s
# 371:	learn: 0.4172811	total: 30.9s	remaining: 52.2s
# 372:	learn: 0.4172605	total: 31s	remaining: 52.1s
# 373:	learn: 0.4172423	total: 31s	remaining: 52s
# 374:	learn: 0.4172318	total: 31.1s	remaining: 51.9s
# 375:	learn: 0.4172148	total: 31.2s	remaining: 51.8s
# 376:	learn: 0.4171960	total: 31.3s	remaining: 51.7s
# 377:	learn: 0.4171767	total: 31.3s	remaining: 51.6s
# 378:	learn: 0.4171576	total: 31.4s	remaining: 51.5s
# 379:	learn: 0.4171364	total: 31.5s	remaining: 51.4s
# 380:	learn: 0.4171191	total: 31.6s	remaining: 51.3s
# 381:	learn: 0.4171012	total: 31.6s	remaining: 51.2s
# 382:	learn: 0.4170858	total: 31.7s	remaining: 51.1s
# 383:	learn: 0.4170717	total: 31.8s	remaining: 51.1s
# 384:	learn: 0.4170520	total: 32s	remaining: 51.1s
# 385:	learn: 0.4170325	total: 32.1s	remaining: 51.1s
# 386:	learn: 0.4170121	total: 32.2s	remaining: 51s
# 387:	learn: 0.4169948	total: 32.4s	remaining: 51s
# 388:	learn: 0.4169811	total: 32.5s	remaining: 51s
# 389:	learn: 0.4169662	total: 32.6s	remaining: 51s
# 390:	learn: 0.4169551	total: 32.7s	remaining: 51s
# 391:	learn: 0.4169349	total: 32.8s	remaining: 50.9s
# 392:	learn: 0.4169202	total: 32.9s	remaining: 50.9s
# 393:	learn: 0.4169009	total: 33.1s	remaining: 50.9s
# 394:	learn: 0.4168844	total: 33.2s	remaining: 50.8s
# 395:	learn: 0.4168626	total: 33.3s	remaining: 50.8s
# 396:	learn: 0.4168481	total: 33.5s	remaining: 50.8s
# 397:	learn: 0.4168325	total: 33.6s	remaining: 50.8s
# 398:	learn: 0.4168177	total: 33.7s	remaining: 50.8s
# 399:	learn: 0.4167978	total: 33.9s	remaining: 50.8s
# 400:	learn: 0.4167862	total: 34s	remaining: 50.8s
# 401:	learn: 0.4167689	total: 34.1s	remaining: 50.8s
# 402:	learn: 0.4167482	total: 34.3s	remaining: 50.8s
# 403:	learn: 0.4167264	total: 34.4s	remaining: 50.8s
# 404:	learn: 0.4167054	total: 34.5s	remaining: 50.8s
# 405:	learn: 0.4166884	total: 34.7s	remaining: 50.7s
# 406:	learn: 0.4166726	total: 34.8s	remaining: 50.7s
# 407:	learn: 0.4166590	total: 34.9s	remaining: 50.7s
# 408:	learn: 0.4166440	total: 35.1s	remaining: 50.7s
# 409:	learn: 0.4166248	total: 35.2s	remaining: 50.6s
# 410:	learn: 0.4166111	total: 35.3s	remaining: 50.6s
# 411:	learn: 0.4165956	total: 35.4s	remaining: 50.5s
# 412:	learn: 0.4165760	total: 35.5s	remaining: 50.4s
# 413:	learn: 0.4165559	total: 35.5s	remaining: 50.3s
# 414:	learn: 0.4165382	total: 35.6s	remaining: 50.2s
# 415:	learn: 0.4165170	total: 35.7s	remaining: 50.1s
# 416:	learn: 0.4164946	total: 35.8s	remaining: 50s
# 417:	learn: 0.4164778	total: 35.8s	remaining: 49.9s
# 418:	learn: 0.4164615	total: 35.9s	remaining: 49.8s
# 419:	learn: 0.4164408	total: 36s	remaining: 49.7s
# 420:	learn: 0.4164255	total: 36s	remaining: 49.6s
# 421:	learn: 0.4164113	total: 36.1s	remaining: 49.5s
# 422:	learn: 0.4163872	total: 36.2s	remaining: 49.4s
# 423:	learn: 0.4163725	total: 36.3s	remaining: 49.3s
# 424:	learn: 0.4163571	total: 36.4s	remaining: 49.3s
# 425:	learn: 0.4163386	total: 36.6s	remaining: 49.3s
# 426:	learn: 0.4163165	total: 36.7s	remaining: 49.3s
# 427:	learn: 0.4163002	total: 36.8s	remaining: 49.2s
# 428:	learn: 0.4162850	total: 37s	remaining: 49.2s
# 429:	learn: 0.4162682	total: 37.1s	remaining: 49.1s
# 430:	learn: 0.4162481	total: 37.2s	remaining: 49.1s
# 431:	learn: 0.4162310	total: 37.3s	remaining: 49.1s
# 432:	learn: 0.4162146	total: 37.4s	remaining: 49s
# 433:	learn: 0.4161983	total: 37.6s	remaining: 49s
# 434:	learn: 0.4161828	total: 37.6s	remaining: 48.9s
# 435:	learn: 0.4161678	total: 37.7s	remaining: 48.8s
# 436:	learn: 0.4161474	total: 37.8s	remaining: 48.7s
# 437:	learn: 0.4161321	total: 37.9s	remaining: 48.7s
# 438:	learn: 0.4161086	total: 38s	remaining: 48.6s
# 439:	learn: 0.4160844	total: 38.1s	remaining: 48.4s
# 440:	learn: 0.4160724	total: 38.1s	remaining: 48.3s
# 441:	learn: 0.4160535	total: 38.3s	remaining: 48.3s
# 442:	learn: 0.4160390	total: 38.4s	remaining: 48.3s
# 443:	learn: 0.4160199	total: 38.5s	remaining: 48.2s
# 444:	learn: 0.4160017	total: 38.6s	remaining: 48.2s
# 445:	learn: 0.4159889	total: 38.7s	remaining: 48.1s
# 446:	learn: 0.4159754	total: 38.8s	remaining: 48.1s
# 447:	learn: 0.4159553	total: 39s	remaining: 48s
# 448:	learn: 0.4159429	total: 39.1s	remaining: 48s
# 449:	learn: 0.4159312	total: 39.2s	remaining: 48s
# 450:	learn: 0.4159125	total: 39.4s	remaining: 47.9s
# 451:	learn: 0.4158916	total: 39.5s	remaining: 47.9s
# 452:	learn: 0.4158717	total: 39.6s	remaining: 47.8s
# 453:	learn: 0.4158567	total: 39.7s	remaining: 47.8s
# 454:	learn: 0.4158360	total: 39.8s	remaining: 47.7s
# 455:	learn: 0.4158209	total: 40s	remaining: 47.7s
# 456:	learn: 0.4158029	total: 40.1s	remaining: 47.6s
# 457:	learn: 0.4157833	total: 40.2s	remaining: 47.6s
# 458:	learn: 0.4157697	total: 40.3s	remaining: 47.5s
# 459:	learn: 0.4157516	total: 40.4s	remaining: 47.4s
# 460:	learn: 0.4157418	total: 40.5s	remaining: 47.4s
# 461:	learn: 0.4157247	total: 40.6s	remaining: 47.3s
# 462:	learn: 0.4157089	total: 40.7s	remaining: 47.2s
# 463:	learn: 0.4156914	total: 40.8s	remaining: 47.1s
# 464:	learn: 0.4156747	total: 40.9s	remaining: 47.1s
# 465:	learn: 0.4156607	total: 41s	remaining: 47s
# 466:	learn: 0.4156411	total: 41.1s	remaining: 46.9s
# 467:	learn: 0.4156273	total: 41.2s	remaining: 46.8s
# 468:	learn: 0.4156087	total: 41.3s	remaining: 46.7s
# 469:	learn: 0.4155930	total: 41.3s	remaining: 46.6s
# 470:	learn: 0.4155804	total: 41.5s	remaining: 46.6s
# 471:	learn: 0.4155633	total: 41.6s	remaining: 46.5s
# 472:	learn: 0.4155452	total: 41.8s	remaining: 46.5s
# 473:	learn: 0.4155332	total: 41.9s	remaining: 46.5s
# 474:	learn: 0.4155145	total: 42s	remaining: 46.4s
# 475:	learn: 0.4154946	total: 42s	remaining: 46.3s
# 476:	learn: 0.4154780	total: 42.1s	remaining: 46.2s
# 477:	learn: 0.4154586	total: 42.2s	remaining: 46.1s
# 478:	learn: 0.4154403	total: 42.3s	remaining: 46s
# 479:	learn: 0.4154245	total: 42.4s	remaining: 45.9s
# 480:	learn: 0.4154056	total: 42.4s	remaining: 45.8s
# 481:	learn: 0.4153904	total: 42.5s	remaining: 45.7s
# 482:	learn: 0.4153701	total: 42.6s	remaining: 45.6s
# 483:	learn: 0.4153505	total: 42.7s	remaining: 45.5s
# 484:	learn: 0.4153356	total: 42.8s	remaining: 45.4s
# 485:	learn: 0.4153125	total: 42.8s	remaining: 45.3s
# 486:	learn: 0.4152973	total: 42.9s	remaining: 45.2s
# 487:	learn: 0.4152829	total: 43s	remaining: 45.1s
# 488:	learn: 0.4152645	total: 43.1s	remaining: 45.1s
# 489:	learn: 0.4152482	total: 43.2s	remaining: 45s
# 490:	learn: 0.4152338	total: 43.3s	remaining: 44.9s
# 491:	learn: 0.4152208	total: 43.4s	remaining: 44.8s
# 492:	learn: 0.4152032	total: 43.5s	remaining: 44.7s
# 493:	learn: 0.4151824	total: 43.6s	remaining: 44.6s
# 494:	learn: 0.4151719	total: 43.7s	remaining: 44.6s
# 495:	learn: 0.4151542	total: 43.8s	remaining: 44.5s
# 496:	learn: 0.4151389	total: 44s	remaining: 44.5s
# 497:	learn: 0.4151192	total: 44.1s	remaining: 44.4s
# 498:	learn: 0.4151021	total: 44.2s	remaining: 44.4s
# 499:	learn: 0.4150868	total: 44.3s	remaining: 44.3s
# 500:	learn: 0.4150649	total: 44.4s	remaining: 44.2s
# 501:	learn: 0.4150480	total: 44.5s	remaining: 44.2s
# 502:	learn: 0.4150216	total: 44.7s	remaining: 44.1s
# 503:	learn: 0.4150127	total: 44.8s	remaining: 44.1s
# 504:	learn: 0.4149924	total: 44.9s	remaining: 44s
# 505:	learn: 0.4149774	total: 45s	remaining: 44s
# 506:	learn: 0.4149689	total: 45.1s	remaining: 43.9s
# 507:	learn: 0.4149510	total: 45.3s	remaining: 43.8s
# 508:	learn: 0.4149317	total: 45.4s	remaining: 43.8s
# 509:	learn: 0.4149158	total: 45.5s	remaining: 43.7s
# 510:	learn: 0.4148956	total: 45.7s	remaining: 43.7s
# 511:	learn: 0.4148791	total: 45.8s	remaining: 43.6s
# 512:	learn: 0.4148655	total: 45.9s	remaining: 43.6s
# 513:	learn: 0.4148510	total: 46s	remaining: 43.5s
# 514:	learn: 0.4148364	total: 46.1s	remaining: 43.4s
# 515:	learn: 0.4148199	total: 46.2s	remaining: 43.4s
# 516:	learn: 0.4147991	total: 46.4s	remaining: 43.3s
# 517:	learn: 0.4147803	total: 46.5s	remaining: 43.3s
# 518:	learn: 0.4147615	total: 46.6s	remaining: 43.2s
# 519:	learn: 0.4147492	total: 46.7s	remaining: 43.1s
# 520:	learn: 0.4147294	total: 46.9s	remaining: 43.1s
# 521:	learn: 0.4147163	total: 47s	remaining: 43s
# 522:	learn: 0.4147064	total: 47.1s	remaining: 43s
# 523:	learn: 0.4146834	total: 47.2s	remaining: 42.9s
# 524:	learn: 0.4146684	total: 47.3s	remaining: 42.8s
# 525:	learn: 0.4146514	total: 47.4s	remaining: 42.7s
# 526:	learn: 0.4146416	total: 47.5s	remaining: 42.6s
# 527:	learn: 0.4146253	total: 47.6s	remaining: 42.5s
# 528:	learn: 0.4146065	total: 47.7s	remaining: 42.4s
# 529:	learn: 0.4145876	total: 47.8s	remaining: 42.4s
# 530:	learn: 0.4145759	total: 47.8s	remaining: 42.3s
# 531:	learn: 0.4145661	total: 47.9s	remaining: 42.1s
# 532:	learn: 0.4145465	total: 48s	remaining: 42.1s
# 533:	learn: 0.4145279	total: 48.1s	remaining: 42s
# 534:	learn: 0.4145127	total: 48.3s	remaining: 41.9s
# 535:	learn: 0.4144999	total: 48.4s	remaining: 41.9s
# 536:	learn: 0.4144818	total: 48.5s	remaining: 41.8s
# 537:	learn: 0.4144667	total: 48.6s	remaining: 41.8s
# 538:	learn: 0.4144481	total: 48.7s	remaining: 41.7s
# 539:	learn: 0.4144259	total: 48.8s	remaining: 41.6s
# 540:	learn: 0.4144061	total: 48.9s	remaining: 41.5s
# 541:	learn: 0.4143883	total: 49s	remaining: 41.4s
# 542:	learn: 0.4143651	total: 49.1s	remaining: 41.3s
# 543:	learn: 0.4143442	total: 49.1s	remaining: 41.2s
# 544:	learn: 0.4143321	total: 49.2s	remaining: 41.1s
# 545:	learn: 0.4143117	total: 49.4s	remaining: 41.1s
# 546:	learn: 0.4143007	total: 49.5s	remaining: 41s
# 547:	learn: 0.4142893	total: 49.6s	remaining: 40.9s
# 548:	learn: 0.4142770	total: 49.7s	remaining: 40.9s
# 549:	learn: 0.4142588	total: 49.8s	remaining: 40.8s
# 550:	learn: 0.4142428	total: 50s	remaining: 40.7s
# 551:	learn: 0.4142172	total: 50.1s	remaining: 40.6s
# 552:	learn: 0.4142012	total: 50.2s	remaining: 40.6s
# 553:	learn: 0.4141851	total: 50.3s	remaining: 40.5s
# 554:	learn: 0.4141742	total: 50.4s	remaining: 40.4s
# 555:	learn: 0.4141572	total: 50.5s	remaining: 40.3s
# 556:	learn: 0.4141408	total: 50.6s	remaining: 40.2s
# 557:	learn: 0.4141293	total: 50.7s	remaining: 40.2s
# 558:	learn: 0.4141126	total: 50.8s	remaining: 40.1s
# 559:	learn: 0.4141031	total: 50.9s	remaining: 40s
# 560:	learn: 0.4140863	total: 50.9s	remaining: 39.9s
# 561:	learn: 0.4140701	total: 51s	remaining: 39.8s
# 562:	learn: 0.4140596	total: 51.1s	remaining: 39.7s
# 563:	learn: 0.4140456	total: 51.2s	remaining: 39.6s
# 564:	learn: 0.4140269	total: 51.3s	remaining: 39.5s
# 565:	learn: 0.4140136	total: 51.4s	remaining: 39.4s
# 566:	learn: 0.4140028	total: 51.5s	remaining: 39.3s
# 567:	learn: 0.4139896	total: 51.5s	remaining: 39.2s
# 568:	learn: 0.4139797	total: 51.6s	remaining: 39.1s
# 569:	learn: 0.4139574	total: 51.7s	remaining: 39s
# 570:	learn: 0.4139373	total: 51.8s	remaining: 38.9s
# 571:	learn: 0.4139256	total: 51.9s	remaining: 38.8s
# 572:	learn: 0.4139054	total: 51.9s	remaining: 38.7s
# 573:	learn: 0.4138884	total: 52s	remaining: 38.6s
# 574:	learn: 0.4138751	total: 52.1s	remaining: 38.5s
# 575:	learn: 0.4138621	total: 52.2s	remaining: 38.4s
# 576:	learn: 0.4138449	total: 52.3s	remaining: 38.3s
# 577:	learn: 0.4138289	total: 52.3s	remaining: 38.2s
# 578:	learn: 0.4138141	total: 52.4s	remaining: 38.1s
# 579:	learn: 0.4137937	total: 52.5s	remaining: 38s
# 580:	learn: 0.4137791	total: 52.6s	remaining: 37.9s
# 581:	learn: 0.4137621	total: 52.7s	remaining: 37.8s
# 582:	learn: 0.4137478	total: 52.7s	remaining: 37.7s
# 583:	learn: 0.4137295	total: 52.8s	remaining: 37.6s
# 584:	learn: 0.4137143	total: 52.9s	remaining: 37.5s
# 585:	learn: 0.4136931	total: 53s	remaining: 37.4s
# 586:	learn: 0.4136745	total: 53.1s	remaining: 37.3s
# 587:	learn: 0.4136562	total: 53.1s	remaining: 37.2s
# 588:	learn: 0.4136476	total: 53.2s	remaining: 37.1s
# 589:	learn: 0.4136268	total: 53.3s	remaining: 37s
# 590:	learn: 0.4136134	total: 53.4s	remaining: 36.9s
# 591:	learn: 0.4135981	total: 53.5s	remaining: 36.8s
# 592:	learn: 0.4135838	total: 53.6s	remaining: 36.8s
# 593:	learn: 0.4135631	total: 53.6s	remaining: 36.7s
# 594:	learn: 0.4135496	total: 53.7s	remaining: 36.6s
# 595:	learn: 0.4135351	total: 53.8s	remaining: 36.5s
# 596:	learn: 0.4135168	total: 53.9s	remaining: 36.4s
# 597:	learn: 0.4135052	total: 54s	remaining: 36.3s
# 598:	learn: 0.4134924	total: 54s	remaining: 36.2s
# 599:	learn: 0.4134822	total: 54.1s	remaining: 36.1s
# 600:	learn: 0.4134624	total: 54.2s	remaining: 36s
# 601:	learn: 0.4134397	total: 54.3s	remaining: 35.9s
# 602:	learn: 0.4134274	total: 54.4s	remaining: 35.8s
# 603:	learn: 0.4134123	total: 54.5s	remaining: 35.7s
# 604:	learn: 0.4133920	total: 54.6s	remaining: 35.6s
# 605:	learn: 0.4133768	total: 54.6s	remaining: 35.5s
# 606:	learn: 0.4133589	total: 54.7s	remaining: 35.4s
# 607:	learn: 0.4133459	total: 54.8s	remaining: 35.3s
# 608:	learn: 0.4133233	total: 54.9s	remaining: 35.2s
# 609:	learn: 0.4133000	total: 55s	remaining: 35.1s
# 610:	learn: 0.4132923	total: 55s	remaining: 35s
# 611:	learn: 0.4132761	total: 55.1s	remaining: 34.9s
# 612:	learn: 0.4132610	total: 55.2s	remaining: 34.9s
# 613:	learn: 0.4132515	total: 55.3s	remaining: 34.8s
# 614:	learn: 0.4132299	total: 55.4s	remaining: 34.7s
# 615:	learn: 0.4132143	total: 55.5s	remaining: 34.6s
# 616:	learn: 0.4131977	total: 55.5s	remaining: 34.5s
# 617:	learn: 0.4131798	total: 55.6s	remaining: 34.4s
# 618:	learn: 0.4131652	total: 55.7s	remaining: 34.3s
# 619:	learn: 0.4131501	total: 55.8s	remaining: 34.2s
# 620:	learn: 0.4131362	total: 55.9s	remaining: 34.1s
# 621:	learn: 0.4131189	total: 55.9s	remaining: 34s
# 622:	learn: 0.4131077	total: 56s	remaining: 33.9s
# 623:	learn: 0.4130897	total: 56.1s	remaining: 33.8s
# 624:	learn: 0.4130704	total: 56.2s	remaining: 33.7s
# 625:	learn: 0.4130627	total: 56.3s	remaining: 33.6s
# 626:	learn: 0.4130508	total: 56.3s	remaining: 33.5s
# 627:	learn: 0.4130337	total: 56.4s	remaining: 33.4s
# 628:	learn: 0.4130119	total: 56.5s	remaining: 33.3s
# 629:	learn: 0.4129910	total: 56.6s	remaining: 33.2s
# 630:	learn: 0.4129726	total: 56.7s	remaining: 33.1s
# 631:	learn: 0.4129533	total: 56.7s	remaining: 33s
# 632:	learn: 0.4129368	total: 56.8s	remaining: 32.9s
# 633:	learn: 0.4129238	total: 56.9s	remaining: 32.8s
# 634:	learn: 0.4129082	total: 57s	remaining: 32.7s
# 635:	learn: 0.4128933	total: 57s	remaining: 32.6s
# 636:	learn: 0.4128803	total: 57.1s	remaining: 32.6s
# 637:	learn: 0.4128671	total: 57.2s	remaining: 32.5s
# 638:	learn: 0.4128493	total: 57.3s	remaining: 32.4s
# 639:	learn: 0.4128354	total: 57.4s	remaining: 32.3s
# 640:	learn: 0.4128236	total: 57.4s	remaining: 32.2s
# 641:	learn: 0.4128110	total: 57.5s	remaining: 32.1s
# 642:	learn: 0.4127900	total: 57.6s	remaining: 32s
# 643:	learn: 0.4127712	total: 57.7s	remaining: 31.9s
# 644:	learn: 0.4127594	total: 57.7s	remaining: 31.8s
# 645:	learn: 0.4127440	total: 57.8s	remaining: 31.7s
# 646:	learn: 0.4127320	total: 57.9s	remaining: 31.6s
# 647:	learn: 0.4127190	total: 58s	remaining: 31.5s
# 648:	learn: 0.4127051	total: 58.1s	remaining: 31.4s
# 649:	learn: 0.4126909	total: 58.1s	remaining: 31.3s
# 650:	learn: 0.4126749	total: 58.2s	remaining: 31.2s
# 651:	learn: 0.4126566	total: 58.3s	remaining: 31.1s
# 652:	learn: 0.4126438	total: 58.4s	remaining: 31s
# 653:	learn: 0.4126290	total: 58.4s	remaining: 30.9s
# 654:	learn: 0.4126208	total: 58.5s	remaining: 30.8s
# 655:	learn: 0.4126076	total: 58.6s	remaining: 30.7s
# 656:	learn: 0.4125894	total: 58.7s	remaining: 30.6s
# 657:	learn: 0.4125646	total: 58.8s	remaining: 30.5s
# 658:	learn: 0.4125532	total: 58.9s	remaining: 30.5s
# 659:	learn: 0.4125372	total: 58.9s	remaining: 30.4s
# 660:	learn: 0.4125201	total: 59s	remaining: 30.3s
# 661:	learn: 0.4125050	total: 59.1s	remaining: 30.2s
# 662:	learn: 0.4124888	total: 59.2s	remaining: 30.1s
# 663:	learn: 0.4124790	total: 59.2s	remaining: 30s
# 664:	learn: 0.4124655	total: 59.3s	remaining: 29.9s
# 665:	learn: 0.4124514	total: 59.4s	remaining: 29.8s
# 666:	learn: 0.4124268	total: 59.5s	remaining: 29.7s
# 667:	learn: 0.4124082	total: 59.6s	remaining: 29.6s
# 668:	learn: 0.4123984	total: 59.6s	remaining: 29.5s
# 669:	learn: 0.4123815	total: 59.7s	remaining: 29.4s
# 670:	learn: 0.4123602	total: 59.8s	remaining: 29.3s
# 671:	learn: 0.4123439	total: 59.9s	remaining: 29.2s
# 672:	learn: 0.4123315	total: 60s	remaining: 29.1s
# 673:	learn: 0.4123210	total: 1m	remaining: 29s
# 674:	learn: 0.4123035	total: 1m	remaining: 28.9s
# 675:	learn: 0.4122854	total: 1m	remaining: 28.9s
# 676:	learn: 0.4122687	total: 1m	remaining: 28.8s
# 677:	learn: 0.4122565	total: 1m	remaining: 28.7s
# 678:	learn: 0.4122397	total: 1m	remaining: 28.6s
# 679:	learn: 0.4122280	total: 1m	remaining: 28.5s
# 680:	learn: 0.4122091	total: 1m	remaining: 28.4s
# 681:	learn: 0.4121935	total: 1m	remaining: 28.3s
# 682:	learn: 0.4121793	total: 1m	remaining: 28.2s
# 683:	learn: 0.4121609	total: 1m	remaining: 28.1s
# 684:	learn: 0.4121439	total: 1m 1s	remaining: 28.1s
# 685:	learn: 0.4121308	total: 1m 1s	remaining: 28s
# 686:	learn: 0.4121153	total: 1m 1s	remaining: 27.9s
# 687:	learn: 0.4121017	total: 1m 1s	remaining: 27.8s
# 688:	learn: 0.4120802	total: 1m 1s	remaining: 27.7s
# 689:	learn: 0.4120655	total: 1m 1s	remaining: 27.6s
# 690:	learn: 0.4120516	total: 1m 1s	remaining: 27.5s
# 691:	learn: 0.4120354	total: 1m 1s	remaining: 27.4s
# 692:	learn: 0.4120234	total: 1m 1s	remaining: 27.3s
# 693:	learn: 0.4120075	total: 1m 1s	remaining: 27.2s
# 694:	learn: 0.4119919	total: 1m 1s	remaining: 27.1s
# 695:	learn: 0.4119741	total: 1m 1s	remaining: 27s
# 696:	learn: 0.4119601	total: 1m 1s	remaining: 26.9s
# 697:	learn: 0.4119448	total: 1m 2s	remaining: 26.9s
# 698:	learn: 0.4119265	total: 1m 2s	remaining: 26.8s
# 699:	learn: 0.4119106	total: 1m 2s	remaining: 26.7s
# 700:	learn: 0.4118947	total: 1m 2s	remaining: 26.6s
# 701:	learn: 0.4118853	total: 1m 2s	remaining: 26.5s
# 702:	learn: 0.4118782	total: 1m 2s	remaining: 26.4s
# 703:	learn: 0.4118710	total: 1m 2s	remaining: 26.3s
# 704:	learn: 0.4118558	total: 1m 2s	remaining: 26.2s
# 705:	learn: 0.4118450	total: 1m 2s	remaining: 26.1s
# 706:	learn: 0.4118252	total: 1m 2s	remaining: 26s
# 707:	learn: 0.4118118	total: 1m 2s	remaining: 25.9s
# 708:	learn: 0.4117979	total: 1m 2s	remaining: 25.8s
# 709:	learn: 0.4117830	total: 1m 3s	remaining: 25.8s
# 710:	learn: 0.4117634	total: 1m 3s	remaining: 25.7s
# 711:	learn: 0.4117451	total: 1m 3s	remaining: 25.6s
# 712:	learn: 0.4117238	total: 1m 3s	remaining: 25.5s
# 713:	learn: 0.4117081	total: 1m 3s	remaining: 25.4s
# 714:	learn: 0.4116927	total: 1m 3s	remaining: 25.3s
# 715:	learn: 0.4116744	total: 1m 3s	remaining: 25.2s
# 716:	learn: 0.4116552	total: 1m 3s	remaining: 25.1s
# 717:	learn: 0.4116380	total: 1m 3s	remaining: 25s
# 718:	learn: 0.4116248	total: 1m 3s	remaining: 24.9s
# 719:	learn: 0.4116064	total: 1m 3s	remaining: 24.8s
# 720:	learn: 0.4115949	total: 1m 3s	remaining: 24.7s
# 721:	learn: 0.4115808	total: 1m 4s	remaining: 24.6s
# 722:	learn: 0.4115664	total: 1m 4s	remaining: 24.5s
# 723:	learn: 0.4115520	total: 1m 4s	remaining: 24.5s
# 724:	learn: 0.4115396	total: 1m 4s	remaining: 24.4s
# 725:	learn: 0.4115234	total: 1m 4s	remaining: 24.3s
# 726:	learn: 0.4115103	total: 1m 4s	remaining: 24.2s
# 727:	learn: 0.4114945	total: 1m 4s	remaining: 24.1s
# 728:	learn: 0.4114774	total: 1m 4s	remaining: 24s
# 729:	learn: 0.4114638	total: 1m 4s	remaining: 23.9s
# 730:	learn: 0.4114519	total: 1m 4s	remaining: 23.8s
# 731:	learn: 0.4114390	total: 1m 4s	remaining: 23.7s
# 732:	learn: 0.4114146	total: 1m 4s	remaining: 23.6s
# 733:	learn: 0.4113930	total: 1m 4s	remaining: 23.5s
# 734:	learn: 0.4113825	total: 1m 5s	remaining: 23.4s
# 735:	learn: 0.4113651	total: 1m 5s	remaining: 23.4s
# 736:	learn: 0.4113483	total: 1m 5s	remaining: 23.3s
# 737:	learn: 0.4113372	total: 1m 5s	remaining: 23.2s
# 738:	learn: 0.4113277	total: 1m 5s	remaining: 23.1s
# 739:	learn: 0.4113122	total: 1m 5s	remaining: 23s
# 740:	learn: 0.4112977	total: 1m 5s	remaining: 22.9s
# 741:	learn: 0.4112871	total: 1m 5s	remaining: 22.8s
# 742:	learn: 0.4112710	total: 1m 5s	remaining: 22.7s
# 743:	learn: 0.4112576	total: 1m 5s	remaining: 22.6s
# 744:	learn: 0.4112444	total: 1m 5s	remaining: 22.5s
# 745:	learn: 0.4112308	total: 1m 5s	remaining: 22.4s
# 746:	learn: 0.4112230	total: 1m 6s	remaining: 22.4s
# 747:	learn: 0.4112096	total: 1m 6s	remaining: 22.3s
# 748:	learn: 0.4111955	total: 1m 6s	remaining: 22.2s
# 749:	learn: 0.4111840	total: 1m 6s	remaining: 22.1s
# 750:	learn: 0.4111673	total: 1m 6s	remaining: 22s
# 751:	learn: 0.4111522	total: 1m 6s	remaining: 21.9s
# 752:	learn: 0.4111363	total: 1m 6s	remaining: 21.8s
# 753:	learn: 0.4111219	total: 1m 6s	remaining: 21.7s
# 754:	learn: 0.4111051	total: 1m 6s	remaining: 21.6s
# 755:	learn: 0.4110833	total: 1m 6s	remaining: 21.5s
# 756:	learn: 0.4110661	total: 1m 6s	remaining: 21.4s
# 757:	learn: 0.4110448	total: 1m 6s	remaining: 21.4s
# 758:	learn: 0.4110274	total: 1m 6s	remaining: 21.3s
# 759:	learn: 0.4110066	total: 1m 7s	remaining: 21.2s
# 760:	learn: 0.4109957	total: 1m 7s	remaining: 21.1s
# 761:	learn: 0.4109755	total: 1m 7s	remaining: 21s
# 762:	learn: 0.4109575	total: 1m 7s	remaining: 20.9s
# 763:	learn: 0.4109365	total: 1m 7s	remaining: 20.8s
# 764:	learn: 0.4109226	total: 1m 7s	remaining: 20.7s
# 765:	learn: 0.4109115	total: 1m 7s	remaining: 20.6s
# 766:	learn: 0.4108894	total: 1m 7s	remaining: 20.5s
# 767:	learn: 0.4108727	total: 1m 7s	remaining: 20.4s
# 768:	learn: 0.4108613	total: 1m 7s	remaining: 20.4s
# 769:	learn: 0.4108512	total: 1m 7s	remaining: 20.3s
# 770:	learn: 0.4108345	total: 1m 7s	remaining: 20.2s
# 771:	learn: 0.4108106	total: 1m 8s	remaining: 20.1s
# 772:	learn: 0.4107916	total: 1m 8s	remaining: 20s
# 773:	learn: 0.4107747	total: 1m 8s	remaining: 19.9s
# 774:	learn: 0.4107606	total: 1m 8s	remaining: 19.8s
# 775:	learn: 0.4107472	total: 1m 8s	remaining: 19.7s
# 776:	learn: 0.4107317	total: 1m 8s	remaining: 19.6s
# 777:	learn: 0.4107196	total: 1m 8s	remaining: 19.5s
# 778:	learn: 0.4107001	total: 1m 8s	remaining: 19.5s
# 779:	learn: 0.4106810	total: 1m 8s	remaining: 19.4s
# 780:	learn: 0.4106674	total: 1m 8s	remaining: 19.3s
# 781:	learn: 0.4106575	total: 1m 8s	remaining: 19.2s
# 782:	learn: 0.4106450	total: 1m 8s	remaining: 19.1s
# 783:	learn: 0.4106312	total: 1m 8s	remaining: 19s
# 784:	learn: 0.4106130	total: 1m 9s	remaining: 18.9s
# 785:	learn: 0.4105973	total: 1m 9s	remaining: 18.8s
# 786:	learn: 0.4105815	total: 1m 9s	remaining: 18.7s
# 787:	learn: 0.4105685	total: 1m 9s	remaining: 18.6s
# 788:	learn: 0.4105502	total: 1m 9s	remaining: 18.6s
# 789:	learn: 0.4105341	total: 1m 9s	remaining: 18.5s
# 790:	learn: 0.4105126	total: 1m 9s	remaining: 18.4s
# 791:	learn: 0.4105023	total: 1m 9s	remaining: 18.3s
# 792:	learn: 0.4104864	total: 1m 9s	remaining: 18.2s
# 793:	learn: 0.4104693	total: 1m 9s	remaining: 18.1s
# 794:	learn: 0.4104519	total: 1m 9s	remaining: 18s
# 795:	learn: 0.4104359	total: 1m 9s	remaining: 17.9s
# 796:	learn: 0.4104183	total: 1m 10s	remaining: 17.8s
# 797:	learn: 0.4103982	total: 1m 10s	remaining: 17.7s
# 798:	learn: 0.4103850	total: 1m 10s	remaining: 17.7s
# 799:	learn: 0.4103743	total: 1m 10s	remaining: 17.6s
# 800:	learn: 0.4103607	total: 1m 10s	remaining: 17.5s
# 801:	learn: 0.4103473	total: 1m 10s	remaining: 17.4s
# 802:	learn: 0.4103343	total: 1m 10s	remaining: 17.3s
# 803:	learn: 0.4103245	total: 1m 10s	remaining: 17.2s
# 804:	learn: 0.4103107	total: 1m 10s	remaining: 17.1s
# 805:	learn: 0.4102910	total: 1m 10s	remaining: 17s
# 806:	learn: 0.4102744	total: 1m 10s	remaining: 16.9s
# 807:	learn: 0.4102619	total: 1m 10s	remaining: 16.8s
# 808:	learn: 0.4102466	total: 1m 10s	remaining: 16.8s
# 809:	learn: 0.4102294	total: 1m 11s	remaining: 16.7s
# 810:	learn: 0.4102189	total: 1m 11s	remaining: 16.6s
# 811:	learn: 0.4102056	total: 1m 11s	remaining: 16.5s
# 812:	learn: 0.4101951	total: 1m 11s	remaining: 16.4s
# 813:	learn: 0.4101746	total: 1m 11s	remaining: 16.3s
# 814:	learn: 0.4101582	total: 1m 11s	remaining: 16.2s
# 815:	learn: 0.4101427	total: 1m 11s	remaining: 16.1s
# 816:	learn: 0.4101273	total: 1m 11s	remaining: 16s
# 817:	learn: 0.4101122	total: 1m 11s	remaining: 16s
# 818:	learn: 0.4101017	total: 1m 11s	remaining: 15.9s
# 819:	learn: 0.4100925	total: 1m 11s	remaining: 15.8s
# 820:	learn: 0.4100756	total: 1m 11s	remaining: 15.7s
# 821:	learn: 0.4100640	total: 1m 12s	remaining: 15.6s
# 822:	learn: 0.4100511	total: 1m 12s	remaining: 15.5s
# 823:	learn: 0.4100336	total: 1m 12s	remaining: 15.4s
# 824:	learn: 0.4100210	total: 1m 12s	remaining: 15.3s
# 825:	learn: 0.4100006	total: 1m 12s	remaining: 15.2s
# 826:	learn: 0.4099879	total: 1m 12s	remaining: 15.2s
# 827:	learn: 0.4099750	total: 1m 12s	remaining: 15.1s
# 828:	learn: 0.4099633	total: 1m 12s	remaining: 15s
# 829:	learn: 0.4099432	total: 1m 12s	remaining: 14.9s
# 830:	learn: 0.4099291	total: 1m 12s	remaining: 14.8s
# 831:	learn: 0.4099133	total: 1m 12s	remaining: 14.7s
# 832:	learn: 0.4098984	total: 1m 12s	remaining: 14.6s
# 833:	learn: 0.4098824	total: 1m 12s	remaining: 14.5s
# 834:	learn: 0.4098678	total: 1m 13s	remaining: 14.4s
# 835:	learn: 0.4098558	total: 1m 13s	remaining: 14.4s
# 836:	learn: 0.4098419	total: 1m 13s	remaining: 14.3s
# 837:	learn: 0.4098258	total: 1m 13s	remaining: 14.2s
# 838:	learn: 0.4098130	total: 1m 13s	remaining: 14.1s
# 839:	learn: 0.4098013	total: 1m 13s	remaining: 14s
# 840:	learn: 0.4097865	total: 1m 13s	remaining: 13.9s
# 841:	learn: 0.4097741	total: 1m 13s	remaining: 13.8s
# 842:	learn: 0.4097594	total: 1m 13s	remaining: 13.7s
# 843:	learn: 0.4097440	total: 1m 13s	remaining: 13.6s
# 844:	learn: 0.4097294	total: 1m 13s	remaining: 13.6s
# 845:	learn: 0.4097138	total: 1m 13s	remaining: 13.5s
# 846:	learn: 0.4096948	total: 1m 14s	remaining: 13.4s
# 847:	learn: 0.4096821	total: 1m 14s	remaining: 13.3s
# 848:	learn: 0.4096739	total: 1m 14s	remaining: 13.2s
# 849:	learn: 0.4096643	total: 1m 14s	remaining: 13.1s
# 850:	learn: 0.4096428	total: 1m 14s	remaining: 13s
# 851:	learn: 0.4096287	total: 1m 14s	remaining: 12.9s
# 852:	learn: 0.4096152	total: 1m 14s	remaining: 12.8s
# 853:	learn: 0.4096022	total: 1m 14s	remaining: 12.7s
# 854:	learn: 0.4095919	total: 1m 14s	remaining: 12.7s
# 855:	learn: 0.4095763	total: 1m 14s	remaining: 12.6s
# 856:	learn: 0.4095591	total: 1m 14s	remaining: 12.5s
# 857:	learn: 0.4095444	total: 1m 14s	remaining: 12.4s
# 858:	learn: 0.4095313	total: 1m 14s	remaining: 12.3s
# 859:	learn: 0.4095143	total: 1m 15s	remaining: 12.2s
# 860:	learn: 0.4095039	total: 1m 15s	remaining: 12.1s
# 861:	learn: 0.4094909	total: 1m 15s	remaining: 12s
# 862:	learn: 0.4094809	total: 1m 15s	remaining: 11.9s
# 863:	learn: 0.4094723	total: 1m 15s	remaining: 11.9s
# 864:	learn: 0.4094596	total: 1m 15s	remaining: 11.8s
# 865:	learn: 0.4094389	total: 1m 15s	remaining: 11.7s
# 866:	learn: 0.4094258	total: 1m 15s	remaining: 11.6s
# 867:	learn: 0.4094121	total: 1m 15s	remaining: 11.5s
# 868:	learn: 0.4093994	total: 1m 15s	remaining: 11.4s
# 869:	learn: 0.4093820	total: 1m 15s	remaining: 11.3s
# 870:	learn: 0.4093634	total: 1m 15s	remaining: 11.2s
# 871:	learn: 0.4093524	total: 1m 15s	remaining: 11.2s
# 872:	learn: 0.4093361	total: 1m 16s	remaining: 11.1s
# 873:	learn: 0.4093178	total: 1m 16s	remaining: 11s
# 874:	learn: 0.4093069	total: 1m 16s	remaining: 10.9s
# 875:	learn: 0.4092889	total: 1m 16s	remaining: 10.8s
# 876:	learn: 0.4092731	total: 1m 16s	remaining: 10.7s
# 877:	learn: 0.4092568	total: 1m 16s	remaining: 10.6s
# 878:	learn: 0.4092402	total: 1m 16s	remaining: 10.5s
# 879:	learn: 0.4092245	total: 1m 16s	remaining: 10.4s
# 880:	learn: 0.4092161	total: 1m 16s	remaining: 10.4s
# 881:	learn: 0.4092075	total: 1m 16s	remaining: 10.3s
# 882:	learn: 0.4091931	total: 1m 16s	remaining: 10.2s
# 883:	learn: 0.4091791	total: 1m 16s	remaining: 10.1s
# 884:	learn: 0.4091645	total: 1m 17s	remaining: 10s
# 885:	learn: 0.4091472	total: 1m 17s	remaining: 9.93s
# 886:	learn: 0.4091306	total: 1m 17s	remaining: 9.84s
# 887:	learn: 0.4091161	total: 1m 17s	remaining: 9.75s
# 888:	learn: 0.4091030	total: 1m 17s	remaining: 9.67s
# 889:	learn: 0.4090925	total: 1m 17s	remaining: 9.58s
# 890:	learn: 0.4090743	total: 1m 17s	remaining: 9.49s
# 891:	learn: 0.4090575	total: 1m 17s	remaining: 9.4s
# 892:	learn: 0.4090435	total: 1m 17s	remaining: 9.31s
# 893:	learn: 0.4090305	total: 1m 17s	remaining: 9.22s
# 894:	learn: 0.4090162	total: 1m 17s	remaining: 9.14s
# 895:	learn: 0.4090036	total: 1m 17s	remaining: 9.05s
# 896:	learn: 0.4089873	total: 1m 18s	remaining: 8.96s
# 897:	learn: 0.4089690	total: 1m 18s	remaining: 8.87s
# 898:	learn: 0.4089544	total: 1m 18s	remaining: 8.79s
# 899:	learn: 0.4089429	total: 1m 18s	remaining: 8.7s
# 900:	learn: 0.4089289	total: 1m 18s	remaining: 8.61s
# 901:	learn: 0.4089108	total: 1m 18s	remaining: 8.53s
# 902:	learn: 0.4088918	total: 1m 18s	remaining: 8.44s
# 903:	learn: 0.4088768	total: 1m 18s	remaining: 8.35s
# 904:	learn: 0.4088677	total: 1m 18s	remaining: 8.26s
# 905:	learn: 0.4088507	total: 1m 18s	remaining: 8.18s
# 906:	learn: 0.4088369	total: 1m 18s	remaining: 8.09s
# 907:	learn: 0.4088231	total: 1m 18s	remaining: 8s
# 908:	learn: 0.4088017	total: 1m 19s	remaining: 7.91s
# 909:	learn: 0.4087863	total: 1m 19s	remaining: 7.83s
# 910:	learn: 0.4087796	total: 1m 19s	remaining: 7.74s
# 911:	learn: 0.4087666	total: 1m 19s	remaining: 7.65s
# 912:	learn: 0.4087495	total: 1m 19s	remaining: 7.56s
# 913:	learn: 0.4087359	total: 1m 19s	remaining: 7.47s
# 914:	learn: 0.4087291	total: 1m 19s	remaining: 7.39s
# 915:	learn: 0.4087168	total: 1m 19s	remaining: 7.3s
# 916:	learn: 0.4087012	total: 1m 19s	remaining: 7.21s
# 917:	learn: 0.4086822	total: 1m 19s	remaining: 7.12s
# 918:	learn: 0.4086684	total: 1m 19s	remaining: 7.04s
# 919:	learn: 0.4086559	total: 1m 19s	remaining: 6.95s
# 920:	learn: 0.4086432	total: 1m 19s	remaining: 6.86s
# 921:	learn: 0.4086282	total: 1m 20s	remaining: 6.77s
# 922:	learn: 0.4086166	total: 1m 20s	remaining: 6.69s
# 923:	learn: 0.4086054	total: 1m 20s	remaining: 6.6s
# 924:	learn: 0.4085937	total: 1m 20s	remaining: 6.51s
# 925:	learn: 0.4085680	total: 1m 20s	remaining: 6.42s
# 926:	learn: 0.4085541	total: 1m 20s	remaining: 6.34s
# 927:	learn: 0.4085347	total: 1m 20s	remaining: 6.25s
# 928:	learn: 0.4085210	total: 1m 20s	remaining: 6.16s
# 929:	learn: 0.4085079	total: 1m 20s	remaining: 6.08s
# 930:	learn: 0.4084936	total: 1m 20s	remaining: 5.99s
# 931:	learn: 0.4084789	total: 1m 20s	remaining: 5.9s
# 932:	learn: 0.4084652	total: 1m 20s	remaining: 5.81s
# 933:	learn: 0.4084561	total: 1m 21s	remaining: 5.73s
# 934:	learn: 0.4084365	total: 1m 21s	remaining: 5.64s
# 935:	learn: 0.4084220	total: 1m 21s	remaining: 5.55s
# 936:	learn: 0.4084054	total: 1m 21s	remaining: 5.47s
# 937:	learn: 0.4083887	total: 1m 21s	remaining: 5.38s
# 938:	learn: 0.4083826	total: 1m 21s	remaining: 5.29s
# 939:	learn: 0.4083675	total: 1m 21s	remaining: 5.21s
# 940:	learn: 0.4083530	total: 1m 21s	remaining: 5.12s
# 941:	learn: 0.4083432	total: 1m 21s	remaining: 5.03s
# 942:	learn: 0.4083308	total: 1m 21s	remaining: 4.94s
# 943:	learn: 0.4083181	total: 1m 21s	remaining: 4.86s
# 944:	learn: 0.4082994	total: 1m 21s	remaining: 4.77s
# 945:	learn: 0.4082858	total: 1m 22s	remaining: 4.68s
# 946:	learn: 0.4082663	total: 1m 22s	remaining: 4.59s
# 947:	learn: 0.4082545	total: 1m 22s	remaining: 4.51s
# 948:	learn: 0.4082388	total: 1m 22s	remaining: 4.42s
# 949:	learn: 0.4082261	total: 1m 22s	remaining: 4.33s
# 950:	learn: 0.4082085	total: 1m 22s	remaining: 4.25s
# 951:	learn: 0.4081938	total: 1m 22s	remaining: 4.16s
# 952:	learn: 0.4081783	total: 1m 22s	remaining: 4.07s
# 953:	learn: 0.4081613	total: 1m 22s	remaining: 3.99s
# 954:	learn: 0.4081422	total: 1m 22s	remaining: 3.9s
# 955:	learn: 0.4081288	total: 1m 22s	remaining: 3.81s
# 956:	learn: 0.4081115	total: 1m 22s	remaining: 3.73s
# 957:	learn: 0.4080963	total: 1m 23s	remaining: 3.64s
# 958:	learn: 0.4080840	total: 1m 23s	remaining: 3.55s
# 959:	learn: 0.4080720	total: 1m 23s	remaining: 3.46s
# 960:	learn: 0.4080649	total: 1m 23s	remaining: 3.38s
# 961:	learn: 0.4080511	total: 1m 23s	remaining: 3.29s
# 962:	learn: 0.4080300	total: 1m 23s	remaining: 3.2s
# 963:	learn: 0.4080210	total: 1m 23s	remaining: 3.12s
# 964:	learn: 0.4080034	total: 1m 23s	remaining: 3.03s
# 965:	learn: 0.4079916	total: 1m 23s	remaining: 2.94s
# 966:	learn: 0.4079824	total: 1m 23s	remaining: 2.86s
# 967:	learn: 0.4079648	total: 1m 23s	remaining: 2.77s
# 968:	learn: 0.4079473	total: 1m 23s	remaining: 2.69s
# 969:	learn: 0.4079377	total: 1m 24s	remaining: 2.6s
# 970:	learn: 0.4079242	total: 1m 24s	remaining: 2.51s
# 971:	learn: 0.4079087	total: 1m 24s	remaining: 2.42s
# 972:	learn: 0.4078919	total: 1m 24s	remaining: 2.34s
# 973:	learn: 0.4078702	total: 1m 24s	remaining: 2.25s
# 974:	learn: 0.4078536	total: 1m 24s	remaining: 2.16s
# 975:	learn: 0.4078420	total: 1m 24s	remaining: 2.08s
# 976:	learn: 0.4078303	total: 1m 24s	remaining: 1.99s
# 977:	learn: 0.4078215	total: 1m 24s	remaining: 1.9s
# 978:	learn: 0.4078095	total: 1m 24s	remaining: 1.82s
# 979:	learn: 0.4077941	total: 1m 24s	remaining: 1.73s
# 980:	learn: 0.4077785	total: 1m 25s	remaining: 1.65s
# 981:	learn: 0.4077680	total: 1m 25s	remaining: 1.56s
# 982:	learn: 0.4077553	total: 1m 25s	remaining: 1.48s
# 983:	learn: 0.4077392	total: 1m 25s	remaining: 1.39s
# 984:	learn: 0.4077277	total: 1m 25s	remaining: 1.3s
# 985:	learn: 0.4077165	total: 1m 25s	remaining: 1.21s
# 986:	learn: 0.4076935	total: 1m 25s	remaining: 1.13s
# 987:	learn: 0.4076807	total: 1m 25s	remaining: 1.04s
# 988:	learn: 0.4076676	total: 1m 25s	remaining: 954ms
# 989:	learn: 0.4076492	total: 1m 25s	remaining: 867ms
# 990:	learn: 0.4076269	total: 1m 25s	remaining: 781ms
# 991:	learn: 0.4076082	total: 1m 26s	remaining: 694ms
# 992:	learn: 0.4075932	total: 1m 26s	remaining: 607ms
# 993:	learn: 0.4075816	total: 1m 26s	remaining: 521ms
# 994:	learn: 0.4075686	total: 1m 26s	remaining: 434ms
# 995:	learn: 0.4075484	total: 1m 26s	remaining: 347ms
# 996:	learn: 0.4075392	total: 1m 26s	remaining: 260ms
# 997:	learn: 0.4075190	total: 1m 26s	remaining: 174ms
# 998:	learn: 0.4075037	total: 1m 26s	remaining: 86.7ms
# 999:	learn: 0.4074833	total: 1m 26s	remaining: 0us

# %%
y_pred = estimator.predict_proba(X_test_final)

# %%
y_pred_1 = estimator.predict(X_test_final)

# %%
ros = roc_auc_score(y_test.values, y_pred[:,1])

# %%
ros
# Out:
# 0.5008903175154342

# %%
f1_score(y_test.values, y_pred_1)
# Out:
# 0.9185800237704547

# %%
# fi_cols = num_features + mean_columns.tolist() + text_fi_cols

# %%
# fi_df = pd.DataFrame(zip(estimator.feature_importances_, fi_cols), columns=['importance', 'name'])

# %%
# fi_df.sort_values(by='importance', ascending=False).head(50)
# Out:
#     importance                        name
# 9    31.176258          userid_rating_mean
# 10   24.882241                userid_count
# 8     6.634112                  asin_count
# 17    3.340700                itemid_count
# 11    3.282460  userid_unixReviewTime_mean
# 0     3.263820              unixReviewTime
# 18    3.046550  itemid_unixReviewTime_mean
# 15    2.552658        userid_also_buy_mean
# 12    2.546164           userid_price_mean
# 16    2.477175          itemid_rating_mean
# 13    2.416922            userid_rank_mean
# 14    2.184272       userid_also_view_mean
# 2     1.800444                        rank
# 7     1.739866            asin_rating_mean
# 1     1.545178                       price
# 4     1.459527                    also_buy
# 22    1.224858        itemid_also_buy_mean
# 3     1.143522                   also_view
# 20    0.996910            itemid_rank_mean
# 19    0.851798           itemid_price_mean
# 6     0.745587              verified_count
# 21    0.688980       itemid_also_view_mean
# 5     0.000000        verified_rating_mean

# %%
# rebuilt_data['sqerror'] = (rebuilt_data.rating - rebuilt_data.pred)**2

# %%
# cols = num_features + cat_features + text_features

# %%
# rebuilt_data.columns
# Out:
# Index(['verified', 'asin', 'reviewText', 'summary', 'unixReviewTime', 'userid',
#        'itemid', 'description', 'title', 'brand', 'rank', 'also_view',
#        'main_cat', 'price', 'also_buy', 'category_0', 'category_1',
#        'category_2', 'category_3', 'rating', 'pred', 'sqerror'],
#       dtype='object')

# %%
# rebuilt_data.groupby(['main_cat']).sqerror.agg(['mean', 'count']).\
# sort_values(by=['mean'],ascending=False).head(50)
# Out:
#                               mean  count
# main_cat
# Pet Supplies              0.500000      2
# Tools & Home Improvement  0.500000      2
# Toys & Games              0.357143     14
# Baby                      0.333333      3
# No cat                    0.266667     30
# Sports & Outdoors         0.222222     36
# Grocery                   0.171473  24931
# Amazon Home               0.171171    222
# Health & Personal Care    0.166320    962
# Industrial & Scientific   0.142857     21
# All Beauty                0.134615     52
# Office Products           0.105263     19
# Arts, Crafts & Sewing     0.000000      1
# Home Audio & Theater      0.000000      2

# %%
# f1_score(y_test.values, y_pred_1)

# %%
# fpr, tpr, thresholds = roc_curve(y_test.values, y_pred[:,1])

# %%
# sns.scatterplot(x=fpr, y=tpr)

# %% [markdown]
# ### Prepare LightFM с item/user features

# %%
# features_user = X_train[['verified', 'userid', 'also_view', 'main_cat', 'also_buy']]

# %%
# features_item = X_train[['itemid', 'brand', 'rank', 
#                              'main_cat', 'price', 'category_0', 
#                              'category_1', 'category_2', 'category_3']]

# %%
# df = pd.concat([X_train[['userid', 'itemid',]], y_train], axis=1)
# df_test = pd.concat([X_test[['userid', 'itemid',]], y_test], axis=1)

# %%
features_user = pd.concat([df_mean_train[['verified_rating_mean', 'verified_count',
                                         'userid_rating_mean', 'userid_count', 
                                         'userid_unixReviewTime_mean', 'userid_price_mean', 
                                         'userid_rank_mean', 
                                         'userid_also_view_mean', 'userid_also_buy_mean']], 
                           X_train['userid']], axis=1)

features_item = pd.concat([df_mean_train[['asin_rating_mean', 'asin_count', 'itemid_rating_mean','itemid_count', 
                                          'itemid_unixReviewTime_mean', 'itemid_price_mean', 
                                          'itemid_rank_mean', 'itemid_also_view_mean',
                                          'itemid_also_buy_mean']], 
                           X_train['itemid']], axis=1)

df = pd.concat([X_train[['userid', 'itemid']], y_train], axis=1)
df_test = pd.concat([X_test[['userid', 'itemid']], y_test], axis=1)

# %%
item_f = []
col = []
unique_f1 = []
for column in features_item.drop(['itemid'], axis=1):
    col += [column]*len(features_item[column].unique())
    unique_f1 += list(features_item[column].unique())
for x,y in zip(col, unique_f1):
    res = str(x)+ ":" +str(y)
    item_f.append(res)
    
user_f = []
col = []
unique_f1 = []
for column in features_user.drop(['userid'], axis=1):
    col += [column]*len(features_user[column].unique())
    unique_f1 += list(features_user[column].unique())
for x,y in zip(col, unique_f1):
    res = str(x)+ ":" +str(y)
    user_f.append(res)

# %%
from lightfm.data import Dataset
# we call fit to supply userid, item id and user/item features
dataset = Dataset()
dataset.fit(
        data_sample['userid'].unique(), # all the users
        data_sample['itemid'].unique(), # all the items
        user_features = user_f,
        item_features = item_f
)

# %%
(interactions, weights) = dataset.build_interactions([(x[0], x[1], x[2]) for x in df.values ])

# %%
(interactions_test, weights_test) = dataset.build_interactions([(x[0], x[1], x[2]) for x in df_test.values ])

# %% [markdown]
# ### item_features

# %%
temp_list = []
for column in features_item.drop(['itemid'], axis=1):
    temp_list.append(column + ':')

# %%
def transform_to_list(row):
    """
    Takes as input a list and prepends the columns names to respective values in the list.
    For example: if my_list = [1,1,0,'del'],
    resultant output = ['f1:1', 'f2:1', 'f3:0', 'loc:del']

    """
    result = []
    temp_row = row
    for x,y in zip(temp_list, temp_row):
        res = str(x) +""+ str(y)
        result.append(res)
    return result

# %%
subset = features_item.drop(['itemid'], axis=1)
ad_list = [x.tolist() for x in subset.values]
item_feature_list = []
for item in ad_list:
    item_feature_list.append(transform_to_list(item))

# %%
item_tuple = list(zip(features_item.itemid, item_feature_list))

# %%
item_features = dataset.build_item_features(item_tuple, normalize= False)

# %% [markdown]
# ### user_features

# %%
temp_list = []
for column in features_user.drop(['userid'], axis=1):
    temp_list.append(column + ':')

# %%
subset = features_user.drop(['userid'], axis=1)
ad_list = [x.tolist() for x in subset.values]
user_feature_list = []
for user in ad_list:
    user_feature_list.append(transform_to_list(user))

# %%
user_tuple = list(zip(features_user.userid, user_feature_list))

# %%
user_features = dataset.build_user_features(user_tuple, normalize= False)

# %%
user_id_map, user_feature_map, item_id_map, item_feature_map = dataset.mapping()

# %%
model = LightFM(learning_rate=lr, loss='logistic', no_components=comp, 
                            learning_schedule='adagrad')
model.fit(interactions, # spase matrix representing whether user u and item i interacted
    user_features = user_features,
    item_features = item_features, # we have built the sparse matrix above
    sample_weight = weights, # spase matrix representing how much value to give to user u and item i inetraction: i.e ratings
    epochs=10)

# %%
user_ids = df.userid.apply(lambda x: user_id_map[x])
item_ids = df.itemid.apply(lambda x: item_id_map[x])
preds = model.predict(user_ids.values, item_ids.values, 
                      user_features=user_features, item_features=item_features)

# %%
train_auc = auc_score(model=model,
#                       train_interactions=interactions,
                      test_interactions=interactions,
                      user_features = user_features,
                      item_features=item_features, 
                      check_intersections=True
                     ).mean()

# %%
train_auc

# %%
test_auc = auc_score(model=model,
#                       train_interactions=interactions,
                      test_interactions=interactions_test,
                      user_features = user_features,
                      item_features=item_features, 
                      check_intersections=True
                     ).mean()

# %%
test_auc

# %%
preds_norm = (preds-preds.min()) / (preds-preds.min()).max()

# %%
roc_auc_score(df.rating, preds_norm)
